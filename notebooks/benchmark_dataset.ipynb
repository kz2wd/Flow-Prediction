# %%
from space_exploration.beans.dataset_bean import Dataset

# %%
ds_name = "paper-train"
ds = Dataset.get_dataset_or_fail(ds_name)
benchmark = ds.benchmark

# %%
benchmark.compute()
# Out:
# Computing Benchmark Data
# Saving reynolds_uv
# Saving velocity_mean_along_y
# Saving velocity_std_along_y
# Saving squared_velocity_mean_along_y
# Saved benchmarks for paper-train
