# %%
from space_exploration.beans.training_bean import Training
from space_exploration.training.training import ModelTraining

# %%
run_id = "a05e2c7641e3429f8ee996d745890b43"
bean = Training.get_training_or_fail(run_id)
training = ModelTraining.from_training_bean(bean)

# %%
# Out:
# (32, 64)

# %%
y_dimension = training.dataset.channel.get_simulation_channel().y_dimension

# %%
y_dimension[training.model.prediction_sub_space.y[0]:training.model.prediction_sub_space.y[1]] * 200
# Out:
# array([ 44.48620981,  46.53712113,  48.672313  ,  50.89854819,
#         53.22318437,  55.65422889,  58.20039632,  60.8711677 ,
#         63.67685015,  66.62863457,  69.73864814,  73.01999717,
#         76.486794  ,  80.15415939,  84.03818922,  88.15587089,
#         92.52493092,  97.16359127, 102.09020779, 107.3227612 ,
#        112.87817071, 118.77140399, 125.01436828, 131.61458859,
#        138.57371225, 145.88592626, 153.53643061, 161.50016807,
#        169.74105273, 178.21194372, 186.85555797, 195.60639801])
